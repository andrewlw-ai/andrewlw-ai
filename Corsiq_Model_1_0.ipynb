# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewlw-ai/andrewlw-ai/blob/main/Corsiq_Model_1_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'drive', 'sample_data']

# %%
import pandas as pd

df = pd.read_csv('/loan.csv')  # replace with your file name
df.head()
# Out:
# <ipython-input-5-15a20766bae1>:3: DtypeWarning: Columns (19,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/loan.csv')  # replace with your file name
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    7  \
# ...
